# %% [markdown]
# # Main table cleaning:

# %%
import pandas as pd

# %%
teams_df= pd.read_csv("/Users/vidushi/Documents/Data_Visualization/datasets/olympics/teams.csv")
events_df= pd.read_csv("/Users/vidushi/Documents/Data_Visualization/datasets/olympics/events.csv")

# %%
teams_df.head(2)
# Out:
#                 code  current                        team team_gender  \
# 0  ARCMTEAM3---CHN01     True  People's Republic of China           M
# 1  ARCMTEAM3---COL01     True                    Colombia           M
#
#   country_code   country                country_long discipline  \
# 0          CHN     China  People's Republic of China    Archery
# 1          COL  Colombia                    Colombia    Archery
#
#   disciplines_code      events  \
# 0              ARC  Men's Team
# 1              ARC  Men's Team
#
#                                             athletes coaches  \
# 0        ['KAO Wenchao', 'LI Zhongyuan', 'WANG Yan']     NaN
# 1  ['ARCILA Santiago', 'ENRIQUEZ Jorge', 'HERNAND...     NaN
#
#                       athletes_codes  num_athletes coaches_codes  num_coaches
# 0  ['1913366', '1913367', '1913369']           3.0           NaN          NaN
# 1  ['1935642', '1543412', '1935644']           3.0           NaN          NaN

# %%
teams_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1698 entries, 0 to 1697
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   code              1698 non-null   object
#  1   current           1698 non-null   bool
#  2   team              1698 non-null   object
#  3   team_gender       1698 non-null   object
#  4   country_code      1698 non-null   object
#  5   country           1698 non-null   object
#  6   country_long      1698 non-null   object
#  7   discipline        1698 non-null   object
#  8   disciplines_code  1698 non-null   object
#  9   events            1377 non-null   object
#  10  athletes          1695 non-null   object
#  11  coaches           246 non-null    object
#  12  athletes_codes    1695 non-null   object
#  13  num_athletes      1695 non-null   float64
#  14  coaches_codes     246 non-null    object
#  15  num_coaches       246 non-null    float64
# dtypes: bool(1), float64(2), object(13)
# memory usage: 200.8+ KB

# %%
teams_df= pd.read_csv("/Users/vidushi/Documents/Data_Visualization/datasets/olympics/teams.csv")

specified_columns = ['events', 'athletes', 'coaches', 'athletes_codes', 'num_athletes', 'coaches_codes', 'num_coaches']
missing_data_columns = teams_df[specified_columns].isnull().sum()
missing_data_columns = missing_data_columns[missing_data_columns > 0]
missing_data_columns_list = missing_data_columns.to_dict()
print("Columns with Missing Data:", missing_data_columns_list)
# Out:
# Columns with Missing Data: {'events': 321, 'athletes': 3, 'coaches': 1452, 'athletes_codes': 3, 'num_athletes': 3, 'coaches_codes': 1452, 'num_coaches': 1452}

# %% [markdown]
# # Check for common missinf records

# %%
specified_columns1 = ['events', 'athletes', 'athletes_codes', 'num_athletes']
missing_rows_df = teams_df[specified_columns1]
missing_rows_df = missing_rows_df[teams_df[specified_columns1].isnull().any(axis=1)]
missing_rows_df.shape
# Out:
# (322, 4)

# %% [markdown]
# # Check extra Teams events record comparing to events table

# %%
teams_events_count = teams_df.groupby('events').size().reset_index(name='count')
pd.set_option('display.max_rows', None)  
pd.set_option('display.max_columns', None)  

events_event_count = events_df.groupby('event').size().reset_index(name='count')
pd.set_option('display.max_rows', None)  
pd.set_option('display.max_columns', None) 
print(f"events_event_count : {events_event_count.shape}")
print(f"teams_events_count: {teams_events_count.shape}")
# Out:
# events_event_count : (288, 2)
# teams_events_count: (69, 2)

# %%
unique_in_events = set(events_event_count['event']) - set(teams_events_count['events'])
unique_in_events_df = pd.DataFrame(unique_in_events, columns=['Unique Events in events_event_count'])

print(f"unique_in_events_df : {unique_in_events_df.count()}")
# Out:
# unique_in_events_df : Unique Events in events_event_count    219
# dtype: int64

# %%
unique_in_teams = set(teams_events_count['events']) - set(events_event_count['event'])
unique_in_teams_df = pd.DataFrame(unique_in_teams, columns=['Unique Events in teams_events_count'])
print(f"unique_in_teams_df : {unique_in_teams_df.count()}")
# Out:
# unique_in_teams_df : Unique Events in teams_events_count    0
# dtype: int64

# %% [markdown]
# # Check data where evets is missing

# %%
events_missing_df = teams_df[teams_df['events'].isnull()]
events_missing_df.head(5)
# Out:
#                    code  current                        team team_gender  \
# 915   SHOXARMT----ALG01     True                     Algeria           X
# 1100      T000180168080    False    United States of America           M
# 1103      T005092223144    False                   Australia           W
# 1104      T005105061005    False                 Netherlands           W
# 1105      T005106100046    False  People's Republic of China           W
#
#      country_code        country                country_long discipline  \
# 915           ALG        Algeria                     Algeria   Shooting
# 1100          USA  United States    United States of America   Swimming
# 1103          AUS      Australia                   Australia   Swimming
# 1104          NED    Netherlands                 Netherlands   Swimming
# 1105          CHN          China  People's Republic of China   Swimming
#
#      disciplines_code events  \
# 915               SHO    NaN
# 1100              SWM    NaN
# 1103              SWM    NaN
# 1104              SWM    NaN
# 1105              SWM    NaN
#
#                                                athletes coaches  \
# 915                                                 NaN     NaN
# 1100  ['PHELPS Michael', 'BERENS Richard', 'WALTERS ...     NaN
# 1103  ['SEEBOHM Emily', 'JONES Leisel', 'SCHIPPER Je...     NaN
# 1104  ['DEKKER Inge', 'KROMOWIDJOJO Ranomi', 'HEEMSK...     NaN
# 1105  ['YANG Junxuan', 'TANG Muhan', 'ZHANG Yufei', ...     NaN
#
#                                          athletes_codes  num_athletes  \
# 915                                                 NaN           NaN
# 1100  ['A058159120057', 'A160201175025', 'A158032245...           4.0
# 1103  ['A151028178217', 'A068106140221', 'A112174219...           4.0
# 1104  ['A167210043023', 'A021086173153', 'A099009248...           4.0
# 1105  ['1945159', 'A165186157200', '1945125', '19451...           4.0
#
#      coaches_codes  num_coaches
# 915            NaN          NaN
# 1100           NaN          NaN
# 1103           NaN          NaN
# 1104           NaN          NaN
# 1105           NaN          NaN

# %% [markdown]
# # Check events name from Athelets table

# %% [markdown]
# # Athelets:

# %%
athletes_df= pd.read_csv("/Users/vidushi/Documents/Data_Visualization/datasets/olympics/athletes.csv")
print(athletes_df.columns)
# Out:
# Index(['code', 'current', 'name', 'name_short', 'name_tv', 'gender',
#        'function', 'country_code', 'country', 'country_long', 'nationality',
#        'nationality_long', 'nationality_code', 'height', 'weight',
#        'disciplines', 'events', 'birth_date', 'birth_place', 'birth_country',
#        'residence_place', 'residence_country', 'nickname', 'hobbies',
#        'occupation', 'education', 'family', 'lang', 'coach', 'reason', 'hero',
#        'influence', 'philosophy', 'sporting_relatives', 'ritual',
#        'other_sports'],
#       dtype='object')

# %% [markdown]
# # athletes_codes in teams_df = code in athletes_df

# %%
filtered_athlete = athletes_df[athletes_df['code'] == '1945159']

filtered_athlete
# Out:
#          code  current          name name_short       name_tv  gender  \
# 7863  1945159     True  YANG Junxuan     YANG J  YANG Junxuan  Female
#
#      function country_code country                country_long nationality  \
# 7863  Athlete          CHN   China  People's Republic of China       China
#
#                 nationality_long nationality_code  height  weight  \
# 7863  People's Republic of China              CHN     0.0     0.0
#
#        disciplines                                             events  \
# 7863  ['Swimming']  ["Women's 100m Freestyle", "Women's 200m Frees...
#
#       birth_date birth_place birth_country residence_place residence_country  \
# 7863  2002-01-26        ZIBO         China             NaN             China
#
#                                                nickname  \
# 7863  1101 (because it used to be her number for spo...
#
#                              hobbies occupation                  education  \
# 7863  Drawing, painting, calligraphy    Athlete  Shenzhen University (CHN)
#
#      family      lang                   coach  \
# 7863    NaN  Mandarin  Club: Wang Aimin (CHN)
#
#                                                  reason  \
# 7863  Her parents sent her for swimming lessons and ...
#
#                                                    hero influence philosophy  \
# 7863  Figure skater Hanyu Yuzuru (JPN), two-time Oly...       NaN        NaN
#
#      sporting_relatives ritual other_sports
# 7863                NaN    NaN          NaN

# %%
# Filter rows where 'code' contains the substring 'A'
filtered_athlete = athletes_df[athletes_df['code'].str.contains('A', na=False)]

print(filtered_athlete)
# Out:
# Empty DataFrame
# Columns: [code, current, name, name_short, name_tv, gender, function, country_code, country, country_long, nationality, nationality_long, nationality_code, height, weight, disciplines, events, birth_date, birth_place, birth_country, residence_place, residence_country, nickname, hobbies, occupation, education, family, lang, coach, reason, hero, influence, philosophy, sporting_relatives, ritual, other_sports]
# Index: []

# %%
pd.set_option('display.max_colwidth', None)  # Ensures full column content is displayed

# Display the complete data for athletes and athletes_codes columns
print("Complete data for 'athletes' column:")
print(missed_teams_event['athletes'].head(5))
# Out:
# Complete data for 'athletes' column:
# 915     None
# 1100    None
# 1103    None
# 1104    None
# 1105    None
# Name: athletes, dtype: object

# %%
print("\nComplete data for 'athletes_codes' column:")
print(missed_teams_event['athletes_codes'].head(5))
# Out:
# Complete data for 'athletes_codes' column:
# 915                                                             None
# 1100    [A058159120057, A160201175025, A158032245251, A178191113142]
# 1103    [A151028178217, A068106140221, A112174219072, A045234120065]
# 1104    [A167210043023, A021086173153, A099009248075, A120063251093]
# 1105                      [1945159, A165186157200, 1945125, 1945169]
# Name: athletes_codes, dtype: object

# %% [markdown]
# # Extract the list of athletes_codes from missed_teams_event and flatten it into a single list

# %%
import pandas as pd
import ast

# Convert string representations of lists to actual lists (skip invalid entries)
def safe_literal_eval(value):
    try:
        # Check if the string starts with '[' to identify list-like entries
        if isinstance(value, str) and value.strip().startswith('['):
            return ast.literal_eval(value)
        else:
            return None  # Skip non-list entries (e.g., "Unknown Code")
    except:
        return None

# Apply the function to the column
missed_teams_event['athletes_codes'] = missed_teams_event['athletes_codes'].apply(safe_literal_eval)

# Flatten the list and remove duplicates
flattened_list = list(set(
    item for sublist in missed_teams_event['athletes_codes'].dropna() 
    for item in sublist
))

print("Distinct athletes_codes:")
print(flattened_list)
# Out:
# Distinct athletes_codes:
# ['1924431', 'A14269779', 'A237213152140', 'A14266779', 'A076148192205', '1946150', 'A14824259', 'A103239244077', 'A187196230108', '1935903', 'A14824533', 'A048027092040', 'A107123239192', 'A112254106246', 'A013014102072', 'A036202226007', '1897357', 'A14265932', 'A106069046171', '1902417', 'A254248068097', '1913907', 'A141019169215', 'A125157031143', 'A148153110245', 'A044214191195', '1935982', 'A14202005', 'A14190983', '1903552', '1944397', 'A14354217', '1925686', 'A14269113', 'A046240245098', 'A047125172148', 'A14315831', 'A174247002204', 'A14621683', 'A036188059099', 'A002043086172', '1946183', '1909185', '1920638', 'A043144169008', 'A248100227128', 'A181152204202', 'A14175382', 'A064117133009', '1565150', 'A014186191249', 'A126013073208', '1949294', 'A131115185183', 'A158211185063', '1945214', 'A14190587', 'A184135013064', 'A174033044169', '1897360', '1946146', '1544336', '1945223', '1903627', 'A179104245004', '1939731', '1945200', 'A223114005062', '1954830', 'A160105237070', 'A14888564', 'A010064139153', 'A151028178217', 'A14201894', '1972519', 'A124088024123', 'A175094106066', 'A055231182036', '1903546', 'A224128087103', 'A004161042038', 'A14643508', 'A055051203011', 'A078201013046', 'A022187225221', 'A096000250079', 'A124077066096', '1939870', 'A121240150157', 'A163079108044', 'A14751017', '1903630', 'A131125053101', 'A077158011139', 'A122075111041', 'A14175964', 'A037215200171', 'A14701082', '1981060', 'A000104052206', 'A023244251108', 'A14265621', 'A099009248075', 'A028034008158', '1954849', 'A017172023054', '1903617', 'A211164197017', 'A14314376', 'A098121225180', 'A14596683', 'A191151010042', '1939761', 'A142081230208', 'A075019133031', 'A14356142', 'A077076064179', 'A14630862', 'A102222048157', '1879515', 'A215004066103', '1946212', 'A14321622', '1544338', '1945127', '1962581', '1935896', 'A141158184058', '1919911', '1946218', '1981058', 'A181207103007', '1903621', 'A033149168117', 'A14178860', 'A14888251', '1972546', 'A189113070134', 'A14481678', 'A036175186183', 'A14630863', 'A123253040114', 'A013112022048', 'A14188492', 'A14776879', '1556210', 'A14298709', 'A14722833', 'A078109219032', 'A068001164108', 'A14344697', 'A154165049237', 'A246033113095', 'A124032204008', '1972526', 'A128041107253', '1572548', 'A131060199169', 'A007103221048', '1962582', 'A054120198168', '1967084', 'A14265852', 'A024239122245', 'A202167244056', '1573079', 'A217047140024', 'A14776901', '1572544', 'A158032245251', '1951602', 'A165053232085', '1925635', 'A209242020042', 'A189084131166', 'A14656692', '1935945', 'A14249424', 'A214246009099', 'A124076231199', 'A190103043191', 'A143167102148', 'A119113234225', 'A14309983', 'A14746488', 'A205181238244', 'A14715101', 'A14271480', 'A018172213114', 'A14351412', 'A14313618', 'A061089220080', 'A045234120065', 'A14272094', '1879516', 'A243154025198', 'A14269361', '1967156', 'A223242032146', '1954838', 'A106198218136', 'A233219182239', '1903628', 'A158011114100', '1935907', 'A091104029004', 'A125229139048', 'A188237133158', 'A14247119', 'A14272084', 'A14349647', '1940014', 'A243165246065', 'A160201175025', 'A122227230142', 'A14366027', 'A106078001110', 'A159034078254', 'A063082098069', '1945125', 'A14707842', '1925725', '1924457', 'A14496746', '1890561', '1945166', 'A100069049018', 'A006024194225', 'A14242187', 'A077048168071', 'A226125212007', 'A208029132044', 'A120063251093', 'A126211113164', '1972522', 'A074248051148', '1969203', '1945206', 'A166133200008', 'A178110099020', '1954564', 'A231092067227', 'A205039203030', 'A142232032212', '1935871', '1906698', 'A022123027076', 'A182091034061', 'A228002175119', '1946177', '1889726', '1897365', 'A14351853', '1925633', 'A206148036024', 'A239167219148', 'A251114146078', 'A103108107235', 'A112126046112', '1572557', 'A091152255051', 'A031200236076', '1967119', 'A14254412', 'A14180049', 'A14292474', '1945132', 'A14245966', '1960909', '1950897', 'A070083150062', 'A14370966', '1951507', '1945141', 'A119081160027', 'A129231141123', '1897309', 'A14313000', 'A199 ...

# %%
filtered_list = [code for code in flattened_list if not code.startswith(('A', 'T'))]
print(filtered_list)
# Out:
# ['1924431', '1946150', '1935903', '1897357', '1902417', '1913907', '1935982', '1903552', '1944397', '1925686', '1946183', '1909185', '1920638', '1565150', '1949294', '1945214', '1897360', '1946146', '1544336', '1945223', '1903627', '1939731', '1945200', '1954830', '1972519', '1903546', '1939870', '1903630', '1981060', '1954849', '1903617', '1939761', '1879515', '1946212', '1544338', '1945127', '1962581', '1935896', '1919911', '1946218', '1981058', '1903621', '1972546', '1556210', '1972526', '1572548', '1962582', '1967084', '1573079', '1572544', '1951602', '1925635', '1935945', '1879516', '1967156', '1954838', '1903628', '1935907', '1940014', '1945125', '1925725', '1924457', '1890561', '1945166', '1972522', '1969203', '1945206', '1954564', '1935871', '1906698', '1946177', '1889726', '1897365', '1925633', '1572557', '1967119', '1945132', '1960909', '1950897', '1951507', '1945141', '1897309', '1936000', '1879357', '1945202', '1925681', '1920639', '1945146', '1573098', '1903541', '1939764', '1945157', '1967105', '1935938', '1903557', '1909132', '1945144', '1972542', '1901612', '1903554', '1564261', '1923529', '1962588', '1913945', '1573012', '1902144', '1573185', '1935943', '1935895', '1935901', '1928047', '1962583', '1935957', '1925669', '1923517', '1946200', '1913951', '1923518', '1949301', '1935979', '1967063', '1565166', '1903545', '1949673', '1944354', '1920640', '1543474', '1945159', '1935869', '1946224', '1935932', '1910399', '1879462', '1935998', '2013979', '1538159', '1935923', '1889730', '1572549', '1904727', '1945148', '1967104', '1924442', '1962576', '1981055', '1915338', '1544335', '1960667', '1969182', '1902130', '1538505', '1906348', '1952123', '1945134', '1925678', '1946227', '1967108', '1913899', '1945128', '1972545', '1921599', '1540717', '1945169', '1956469', '1969218', '1903550', '1967074', '1945149', '1902960', '1935918', '1925636', '1946198', '1967065', '1946187', '1939734', '1946155', '1972550', '1925684', '1893076', '1879467', '1936874', '1917559', '1940003', '1936598', '1935882', '1967057', '1935984', '1945164', '1906372', '1925690']

# %%
matched_codes = [code for code in filtered_list if code in athletes_df['code'].values]
print("Matched Codes:")
print(matched_codes)
# Out:
# Matched Codes:
# ['1924431', '1946150', '1935903', '1897357', '1902417', '1913907', '1935982', '1903552', '1944397', '1925686', '1946183', '1909185', '1920638', '1565150', '1949294', '1945214', '1897360', '1946146', '1544336', '1945223', '1903627', '1945200', '1954830', '1972519', '1903546', '1939870', '1903630', '1981060', '1954849', '1903617', '1939761', '1879515', '1946212', '1544338', '1945127', '1962581', '1935896', '1919911', '1946218', '1981058', '1903621', '1972546', '1556210', '1972526', '1572548', '1962582', '1967084', '1573079', '1572544', '1951602', '1925635', '1935945', '1879516', '1967156', '1954838', '1903628', '1935907', '1940014', '1945125', '1925725', '1924457', '1890561', '1945166', '1972522', '1969203', '1945206', '1954564', '1935871', '1906698', '1946177', '1889726', '1897365', '1925633', '1572557', '1967119', '1945132', '1960909', '1950897', '1951507', '1945141', '1897309', '1936000', '1879357', '1945202', '1925681', '1920639', '1945146', '1573098', '1903541', '1939764', '1945157', '1967105', '1935938', '1903557', '1909132', '1945144', '1972542', '1901612', '1903554', '1564261', '1923529', '1962588', '1913945', '1573012', '1902144', '1573185', '1935943', '1935895', '1935901', '1928047', '1962583', '1935957', '1925669', '1923517', '1946200', '1913951', '1923518', '1949301', '1935979', '1967063', '1565166', '1903545', '1949673', '1944354', '1920640', '1543474', '1945159', '1935869', '1946224', '1935932', '1910399', '1879462', '1935998', '2013979', '1538159', '1935923', '1889730', '1572549', '1904727', '1945148', '1967104', '1924442', '1962576', '1981055', '1915338', '1544335', '1960667', '1969182', '1902130', '1538505', '1906348', '1952123', '1945134', '1925678', '1946227', '1967108', '1913899', '1945128', '1972545', '1921599', '1540717', '1945169', '1956469', '1969218', '1903550', '1967074', '1945149', '1902960', '1935918', '1925636', '1946198', '1967065', '1946187', '1939734', '1946155', '1972550', '1925684', '1893076', '1879467', '1936874', '1917559', '1940003', '1936598', '1935882', '1967057', '1935984', '1945164', '1906372', '1925690']

# %%
# Fetch rows from athletes_df where the code matches the values in matched_codes
matched_athletes = athletes_df[athletes_df['code'].isin(matched_codes)]
matched_events_and_codes = matched_athletes[['events', 'code']]

matched_events_and_codes.head(5)
# Out:
#                                                                         events  \
# 263  ['10m Air Pistol Women', '25m Pistol Women', '10m Air Pistol Mixed Team']
# 305                 ["Women's 100m", "Women's 200m", "Women's 4 x 100m Relay"]
# 457                                 ["Women's 200m", "Women's 4 x 100m Relay"]
# 617                                                           ["Women's 400m"]
# 680                                                   ["Men's 4 x 400m Relay"]
#
#         code
# 263  1538159
# 305  1538505
# 457  1540717
# 617  1543474
# 680  1544335

# %%
missed_teams_event['athletes'])

# %%
# Convert string representations of lists to actual lists (skip invalid entries)
def safe_literal_eval(value):
    try:
        # Check if the string starts with '[' to identify list-like entries
        if isinstance(value, str) and value.strip().startswith('['):
            return ast.literal_eval(value)
        else:
            return None  # Skip non-list entries (e.g., "Unknown Athlete")
    except:
        return None

# Apply the function to the column
missed_teams_event['athletes'] = missed_teams_event['athletes'].apply(safe_literal_eval)

# Flatten the list of athletes and remove duplicates
flattened_athletes_list = list(set(
    item for sublist in missed_teams_event['athletes'].dropna() 
    for item in sublist
))

# Display the flattened list of distinct athletes
print("Distinct Athletes:")
print(flattened_athletes_list)
# Out:
# Distinct Athletes:
# []

# %% [markdown]
# # clean the dataset

# %%
teams_df_cleaned = teams_df.dropna(subset=['athletes', 'athletes_codes', 'num_athletes'])
teams_df_cleaned['events'] = teams_df_cleaned['events'].fillna('UNKNOWN')
print(f"Original DataFrame shape: {teams_df.shape}")
print(f"Cleaned DataFrame shape: {teams_df_cleaned.shape}")
print("\nMissing values after cleaning:")
print(teams_df_cleaned[['athletes', 'athletes_codes', 'num_athletes', 'events']].isnull().sum())
cleaned_file_path = "/Users/vidushi/Documents/Data_Visualization/datasets/olympics/cleaned_teams.csv"
teams_df_cleaned.to_csv(cleaned_file_path, index=False)
print(f"Cleaned data saved to: {cleaned_file_path}")
# Out:
# Original DataFrame shape: (1698, 13)
# Cleaned DataFrame shape: (1698, 13)
#
# Missing values after cleaning:
# athletes          0
# athletes_codes    0
# num_athletes      0
# events            0
# dtype: int64
# Cleaned data saved to: /Users/vidushi/Documents/Data_Visualization/datasets/olympics/cleaned_teams.csv

# %% [markdown]
# # Clean data check

# %% [markdown]
# Udf compare_dataframes

# %%
def compare_dataframes(original_df, cleaned_df):
    print("Columns in original but not in cleaned:")
    print(set(original_df.columns) - set(cleaned_df.columns))
    print("\nColumns in cleaned but not in original:")
    print(set(cleaned_df.columns) - set(original_df.columns))
    print(f"\nOriginal shape: {original_df.shape}")
    print(f"Cleaned shape: {cleaned_df.shape}")
    print("\nMissing values in original:")
    print(original_df.isnull().sum())
    print("\nMissing values in cleaned:")
    print(cleaned_df.isnull().sum())
    print(f"Duplicates in cleaned: {cleaned_df.duplicated().sum()}")
    # print("\nRows in original but not in cleaned:")
    diff1 = pd.concat([original_df, cleaned_df, cleaned_df]).drop_duplicates(keep=False)
    print(diff1.head())
    print("\nRows in cleaned but not in original:")
    diff2 = pd.concat([cleaned_df, original_df, original_df]).drop_duplicates(keep=False)
    print(diff2.head())

# %% [markdown]
# # medallists

# %%
original_path = pd.read_csv('/Users/vidushi/PycharmProjects/Data_visualization/Files/Original/medallists.csv')
cleaned_path = pd.read_csv('/Users/vidushi/PycharmProjects/Data_visualization/Files/Cleaned/medallists_data.csv')
compare_dataframes(original_path, cleaned_path)
# Out:
# Columns in original but not in cleaned:
# {'country_long', 'url_event', 'nationality_code', 'nationality', 'nationality_long'}
#
# Columns in cleaned but not in original:
# set()
#
# Original shape: (2315, 21)
# Cleaned shape: (2315, 16)
#
# Missing values in original:
# medal_date            0
# medal_type            0
# medal_code            1
# name                  0
# gender                0
# country_code          0
# country               0
# country_long          0
# nationality_code      1
# nationality           1
# nationality_long      1
# team                760
# team_gender         760
# discipline            0
# event                 0
# event_type            0
# url_event            21
# birth_date            0
# code_athlete          0
# code_team           760
# is_medallist          0
# dtype: int64
#
# Missing values in cleaned:
# medal_date      0
# medal_type      0
# medal_code      0
# name            0
# gender          0
# country_code    0
# country         0
# team            0
# team_gender     0
# discipline      0
# event           0
# event_type      0
# birth_date      0
# code_athlete    0
# code_team       0
# is_medallist    0
# dtype: int64
# Duplicates in cleaned: 0
#
# Rows in original but not in cleaned:
#    medal_date    medal_type  medal_code             name  gender country_code  \
# 0  2024-07-27    Gold Medal         1.0  EVENEPOEL Remco    Male          BEL
# 1  2024-07-27  Silver Medal         2.0    GANNA Filippo    Male          ITA
# 2  2024-07-27  Bronze Medal         3.0    van AERT Wout    Male          BEL
# 3  2024-07-27    Gold Medal         1.0      BROWN Grace  Female          AUS
# 4  2024-07-27  Silver Medal         2.0   HENDERSON Anna  Female          GBR
#
#          country   country_long nationality_code    nationality  \
# 0        Belgium        Belgium              BEL        Belgium
# 1          Italy          Italy              ITA          Italy
# 2        Belgium        Belgium              BEL        Belgium
# 3      Australia      Australia              AUS      Australia
# 4  Great Britain  Great Britain              GBR  Great Britain
#
#   nationality_long team team_gender    discipline  \
# 0          Belgium  NaN         NaN  Cycling Road
# 1            Italy  NaN         NaN  Cycling Road
# 2          Belgium  NaN         NaN  Cycling Road
# 3        Australia  NaN         NaN  Cycling Road
# 4    Great Britain  NaN         NaN  Cycling Road
#
#                            event event_type  \
# 0    Men's Individual Time Trial        ATH
# 1    Men's Individual Time Trial        ATH
# 2    Men's Individual Time Trial        ATH
# 3  Women's Individual Time Trial        ATH
# 4  Women's Individual Time Trial        ATH
#
#                                            url_event  birth_date  \
# 0  /en/paris-2024/results/cycling-road/men-s-indi...  2000-01-25
# 1  /en/paris-2024/results/cycling-road/men-s-indi...  1996-07-25
# 2  /en/paris-2024/results/cycling-road/men-s-indi...  1994-09-15
# 3  /en/paris-2024/results/cycling-road/women-s-in...  1992-07-07
# 4  /en/paris-2024/results/cycling-road/women-s-in...  1998-11-14
#
#    code_athlete code_team  is_medallist
# 0       1903136       NaN          True
# 1       1923520       NaN          True
# 2       1903147       NaN          True
# 3       1940173       NaN          True
# 4       1912525       NaN          True
#
# Rows in cleaned but not in original:
#    medal_date    medal_type  medal_code             name  gender country_code  \
# 0  2024-07-27    Gold Medal         1.0  Remco Evenepoel    Male          BEL
# 1  2024-07-27  Silver Medal         2.0    Filippo Ganna    Male          ITA
# 2  2024-07-27  Bronze Medal         3.0    Van Aert Wout    Male          BEL
# 3  2024-07-27    Gold Medal         1.0      Grace Brown  Female          AUS
# 4  2024-07-27  Silver Medal         2.0   Anna Henderson  Female          GBR
#
#          country     team team_gender    discipline  \
# 0        Belgium  UNKNOWN     UNKNOWN  Cycling Road
# 1          Italy  UNKNOWN     UNKNOWN  Cycling Road
# 2        Belgium  UNKNOWN     UNKNOWN  Cycling Road
# 3      Australia  UNKNOWN     UNKNOWN  Cycling Road
# 4  Great Britain  UNKNOWN     UNKNOWN  Cycling Road
#
#                            event event_type  birth_date  code_athlete  \
# 0    Men's Individual Time Trial        ATH  2000-01-25       1903136
# 1    Men's Individual Time Trial        ATH  1996-07-25       1923520
# 2    Men's Individual Time Trial        ATH  1994-09-15       1903147
# 3  Women's Individual Time Trial        ATH  1992-07-07       1940173
# 4  Women's Individual Time Trial        ATH  1998-11-14       1912525
#
#   code_team  is_medallist country_long nationality_code nationality  \
# 0   UNKNOWN          True          NaN              NaN         NaN
# 1   UNKNOWN          True          NaN              NaN         NaN
# 2   UNKNOWN          True          NaN              NaN         NaN
# 3   UNKNOWN          True          NaN              NaN         NaN
# 4   UNKNOWN          True          NaN              NaN         NaN
#
#   nationality_long url_event
# 0              NaN       NaN
# 1              NaN       NaN
# 2              NaN       NaN
# 3              NaN       NaN
# 4              NaN       NaN

# %% [markdown]
# # medals

# %%
cleaned_path = pd.read_csv('/Users/vidushi/PycharmProjects/Data_visualization/Files/Cleaned/medals_data.csv')
original_path = pd.read_csv('/Users/vidushi/PycharmProjects/Data_visualization/Files/Original/medals.csv')
compare_dataframes(original_path, cleaned_path)
# Out:
# Columns in original but not in cleaned:
# {'url_event', 'country_long'}
#
# Columns in cleaned but not in original:
# set()
#
# Original shape: (1044, 13)
# Cleaned shape: (1044, 11)
#
# Missing values in original:
# medal_type      0
# medal_code      1
# medal_date      0
# name            0
# gender          0
# discipline      0
# event           0
# event_type      0
# url_event       9
# code            0
# country_code    0
# country         0
# country_long    0
# dtype: int64
#
# Missing values in cleaned:
# medal_type      0
# medal_code      0
# medal_date      0
# name            0
# gender          0
# discipline      0
# event           0
# event_type      0
# code            0
# country_code    0
# country         0
# dtype: int64
# Duplicates in cleaned: 0
#
# Rows in original but not in cleaned:
#      medal_type  medal_code  medal_date             name gender    discipline  \
# 0    Gold Medal         1.0  2024-07-27  Remco EVENEPOEL      M  Cycling Road
# 1  Silver Medal         2.0  2024-07-27    Filippo GANNA      M  Cycling Road
# 2  Bronze Medal         3.0  2024-07-27    Wout van AERT      M  Cycling Road
# 3    Gold Medal         1.0  2024-07-27      Grace BROWN      W  Cycling Road
# 4  Silver Medal         2.0  2024-07-27   Anna HENDERSON      W  Cycling Road
#
#                            event event_type  \
# 0    Men's Individual Time Trial        ATH
# 1    Men's Individual Time Trial        ATH
# 2    Men's Individual Time Trial        ATH
# 3  Women's Individual Time Trial        ATH
# 4  Women's Individual Time Trial        ATH
#
#                                            url_event     code country_code  \
# 0  /en/paris-2024/results/cycling-road/men-s-indi...  1903136          BEL
# 1  /en/paris-2024/results/cycling-road/men-s-indi...  1923520          ITA
# 2  /en/paris-2024/results/cycling-road/men-s-indi...  1903147          BEL
# 3  /en/paris-2024/results/cycling-road/women-s-in...  1940173          AUS
# 4  /en/paris-2024/results/cycling-road/women-s-in...  1912525          GBR
#
#          country   country_long
# 0        Belgium        Belgium
# 1          Italy          Italy
# 2        Belgium        Belgium
# 3      Australia      Australia
# 4  Great Britain  Great Britain
#
# Rows in cleaned but not in original:
#      medal_type  medal_code  medal_date             name gender    discipline  \
# 0    Gold Medal         1.0  2024-07-27  Remco EVENEPOEL      M  Cycling Road
# 1  Silver Medal         2.0  2024-07-27    Filippo GANNA      M  Cycling Road
# 2  Bronze Medal         3.0  2024-07-27    Wout van AERT      M  Cycling Road
# 3    Gold Medal         1.0  2024-07-27      Grace BROWN      W  Cycling Road
# 4  Silver Medal         2.0  2024-07-27   Anna HENDERSON      W  Cycling Road
#
#                            event event_type     code country_code  \
# 0    Men's Individual Time Trial        ATH  1903136          BEL
# 1    Men's Individual Time Trial        ATH  1923520          ITA
# 2    Men's Individual Time Trial        ATH  1903147          BEL
# 3  Women's Individual Time Trial        ATH  1940173          AUS
# 4  Women's Individual Time Trial        ATH  1912525          GBR
#
#          country url_event country_long
# 0        Belgium       NaN          NaN
# 1          Italy       NaN          NaN
# 2        Belgium       NaN          NaN
# 3      Australia       NaN          NaN
# 4  Great Britain       NaN          NaN

# %% [markdown]
# # events

# %%
cleaned_path = pd.read_csv('/Users/vidushi/PycharmProjects/Data_visualization/Files/Cleaned/events.csv')
original_path = pd.read_csv('/Users/vidushi/PycharmProjects/Data_visualization/Files/Original/events.csv')
compare_dataframes(original_path, cleaned_path)
# Out:
# Columns in original but not in cleaned:
# {'event'}
#
# Columns in cleaned but not in original:
# {'events'}
#
# Original shape: (329, 5)
# Cleaned shape: (329, 5)
#
# Missing values in original:
# event         0
# tag           0
# sport         0
# sport_code    0
# sport_url     0
# dtype: int64
#
# Missing values in cleaned:
# events        0
# tag           0
# sport         0
# sport_code    0
# sport_url     0
# dtype: int64
# Duplicates in cleaned: 0
#
# Rows in original but not in cleaned:
#                 event      tag    sport sport_code  \
# 0    Men's Individual  archery  Archery        ARC
# 1  Women's Individual  archery  Archery        ARC
# 2          Men's Team  archery  Archery        ARC
# 3        Women's Team  archery  Archery        ARC
# 4          Mixed Team  archery  Archery        ARC
#
#                                            sport_url events
# 0  https://olympics.com/en/paris-2024/sports/archery    NaN
# 1  https://olympics.com/en/paris-2024/sports/archery    NaN
# 2  https://olympics.com/en/paris-2024/sports/archery    NaN
# 3  https://olympics.com/en/paris-2024/sports/archery    NaN
# 4  https://olympics.com/en/paris-2024/sports/archery    NaN
#
# Rows in cleaned but not in original:
#                events      tag    sport sport_code  \
# 0    Men's Individual  archery  Archery        ARC
# 1  Women's Individual  archery  Archery        ARC
# 2          Men's Team  archery  Archery        ARC
# 3        Women's Team  archery  Archery        ARC
# 4          Mixed Team  archery  Archery        ARC
#
#                                            sport_url event
# 0  https://olympics.com/en/paris-2024/sports/archery   NaN
# 1  https://olympics.com/en/paris-2024/sports/archery   NaN
# 2  https://olympics.com/en/paris-2024/sports/archery   NaN
# 3  https://olympics.com/en/paris-2024/sports/archery   NaN
# 4  https://olympics.com/en/paris-2024/sports/archery   NaN

# %% [markdown]
# # medal_total

# %%
cleaned_path = pd.read_csv('/Users/vidushi/PycharmProjects/Data_visualization/Files/Cleaned/medals_total.csv')
original_path = pd.read_csv('/Users/vidushi/PycharmProjects/Data_visualization/Files/Original/medals_total.csv')
compare_dataframes(original_path, cleaned_path)
# Out:
# Columns in original but not in cleaned:
# set()
#
# Columns in cleaned but not in original:
# set()
#
# Original shape: (92, 7)
# Cleaned shape: (92, 7)
#
# Missing values in original:
# country_code    0
# country         0
# country_long    0
# Gold Medal      0
# Silver Medal    0
# Bronze Medal    0
# Total           0
# dtype: int64
#
# Missing values in cleaned:
# country_code    0
# country         0
# country_long    0
# Gold Medal      0
# Silver Medal    0
# Bronze Medal    0
# Total           0
# dtype: int64
# Duplicates in cleaned: 0
# Empty DataFrame
# Columns: [country_code, country, country_long, Gold Medal, Silver Medal, Bronze Medal, Total]
# Index: []
#
# Rows in cleaned but not in original:
# Empty DataFrame
# Columns: [country_code, country, country_long, Gold Medal, Silver Medal, Bronze Medal, Total]
# Index: []

# %% [markdown]
# # Country

# %%
countries_with_flags=pd.read_csv("/Users/vidushi/PycharmProjects/Data_visualization/Files/Cleaned/countries_with_flags.csv")
countries_with_flags
# Out:
#                                      Country Name      Continent  \
# 0                                   South Georgia     Antarctica
# 1                                         Grenada  North America
# 2                                     Switzerland         Europe
# 3                                    Sierra Leone         Africa
# 4                                         Hungary         Europe
# 5                                          Taiwan           Asia
# 6                               Wallis and Futuna        Oceania
# 7                                        Barbados  North America
# 8                                Pitcairn Islands        Oceania
# 9                                     Ivory Coast         Africa
# 10                                        Tunisia         Africa
# 11                                          Italy         Europe
# 12                                          Benin         Africa
# 13                                      Indonesia           Asia
# 14                                     Cape Verde         Africa
# 15                          Saint Kitts and Nevis  North America
# 16                                           Laos           Asia
# 17                          Caribbean Netherlands  North America
# 18                                         Uganda         Africa
# 19                                        Andorra         Europe
# 20                                        Burundi         Africa
# 21                                   South Africa         Africa
# 22                                         France         Europe
# 23                                          Libya         Africa
# 24                                         Mexico  North America
# 25                                          Gabon         Africa
# 26                       Northern Mariana Islands        Oceania
# 27                                North Macedonia         Europe
# 28                                          China           Asia
# 29                                          Yemen           Asia
# 30                               Saint Barthélemy  North America
# 31                                       Guernsey         Europe
# 32                                Solomon Islands        Oceania
# 33                         Svalbard and Jan Mayen         Europe
# 34                                  Faroe Islands         Europe
# 35                                     Uzbekistan           Asia
# 36                                          Egypt         Africa
# 37                                        Senegal         Africa
# 38                                      Sri Lanka           Asia
# 39                                      Palestine           Asia
# 40                                     Bangladesh           Asia
# 41                                           Peru  South America
# 42                                      Singapore           Asia
# 43                                         Turkey         Europe
# 44                                    Afghanistan           Asia
# 45                                          Aruba  North America
# 46                                   Cook Islands        Oceania
# 47                                 United Kingdom         Europe
# 48                                         Zambia         Africa
# 49                                        Finland         Europe
# 50                                          Niger         Africa
# 51                               Christmas Island           Asia
# 52                                        Tokelau        Oceania
# 53                                  Guinea-Bissau         Africa
# 54                                     Azerbaijan         Europe
# 55                                        Réunion         Africa
# 56                                       Djibouti         Africa
# 57                                    North Korea           Asia
# 58                                      Mauritius         Africa
# 59                                     Montserrat  North America
# 60                   United States Virgin Islands  North America
# 61                                       Colombia  South America
# 62                                         Greece         Europe
# 63                                        Croatia         Europe
# 64                                        Morocco         Africa
# 65                                        Algeria         Africa
# 66                                     Antarctica     Antarctica
# 67                                    Netherlands         Europe
# 68                                          Sudan         Africa
# 69                                           Fiji        Oceania
# 70                                  Liechtenstein         Europe
# 71                                          Nepal           Asia
# 72                                    Puerto Rico  North America
# 73                                        Georgia           Asia
# 74                                       Pakistan           Asia
# 75                                         Monaco         Europe
# 76                                       Botswana         Africa
# 77                                        Lebanon           Asia
# 78                               Papua New Guinea        Oceania
# 79                                        Mayotte         Africa
# 80                             Dominican Republic  North America
# 81                                 Norfolk Island        Oceania
# 82                                  Bouvet Island     Antarctica
# 83                                          Qatar           Asia
# 84                                     Madagascar         Africa
# 85                                          India           Asia
# 86                                          Syria           Asia
# 87                                     Montenegro         Europe
# 88                                       Eswatini         Africa
# 89                                       Paraguay  South America
# 90                                    El Salvador  North America
# 91                                        Ukraine         Europe
# 92                                    Isle of Man         Europe
# 93                                        Namibia         Africa
# 94                           United Arab Emirates           Asia
# 95                                       Bulgaria         Europe
# 96                                      Greenland  North America
# 97                                        Germany         Europe
# 98                                       Cambodia           Asia
# 99                                           Iraq           Asia
# 100           French Southern and Antarctic Lands     Antarctica
# 101                                        Sweden         Europe
# 102                                          Cuba  North America
# 103                                    Kyrgyzstan           Asia
# 104                                        Russia         Europe
# 105                                      Malaysia           Asia
# 106                         São Tomé and Príncipe         Africa
# 107                                        Cyprus         Europe
# 108                                        Canada  North America
# 109                                        Malawi         Africa
# 110                                  Saudi Arabia           Asia
# 111                        Bosnia and Herzegovina         Europe
# 112                                      Ethiopia         Africa
# 113                                         Spain         Europe
# 114                                      Slovenia         Europe
# 115                                          Oman           Asia
# 116                     Saint Pierre and Miquelon  North America
# 117                                         Macau           Asia
# 118                                    San Marino         Europe
# 119                                       Lesotho         Africa
# 120                              Marshall Islands        Oceania
# 121                                  Sint Maarten  North America
# 122                                       Iceland         Europe
# 123                                    Luxembourg         Europe
# 124                                     Argentina  South America
# 125                      Turks and Caicos Islands  North America
# 126                                         Nauru        Oceania
# 127                       Cocos (Keeling) Islands           Asia
# 128                                Western Sahara         Africa
# 129                                      Dominica  North America
# 130                                    Costa Rica  North America
# 131                                     Australia        Oceania
# 132                                      Thailand           Asia
# 133                                         Haiti  North America
# 134                                        Tuvalu        Oceania
# 135                                      Honduras  North America
# 136                             Equatorial Guinea         Africa
# 137                                   Saint Lucia  North America
# 138                              French Polynesia        Oceania
# 139                                       Belarus         Europe
# 140                                        Latvia         Europe
# 141                                         Palau        Oceania
# 142                                    Guadeloupe  North America
# 143                                   Philippines           Asia
# 144                                     Gibraltar         Europe
# 145                                       Denmark         Europe
# 146                                      Cameroon         Africa
# 147                                        Guinea         Africa
# 148                                       Bahrain           Asia
# 149                                      Suriname  South America
# 150                                      DR Congo         Africa
# 151                                       Somalia         Africa
# 152                                       Czechia         Europe
# 153                                 New Caledonia        Oceania
# 154                                       Vanuatu        Oceania
# 155  Saint Helena, Ascension and Tristan da Cunha         Africa
# 156                                          Togo         Africa
# 157                        British Virgin Islands  North America
# 158                                         Kenya         Africa
# 159                                          Niue        Oceania
# 160             Heard Island and McDonald Islands     Antarctica
# 161                                        Rwanda         Africa
# 162                                       Estonia         Europe
# 163                                       Romania         Europe
# 164                           Trinidad and Tobago  North America
# 165                                        Guyana  South America
# 166                                   Timor-Leste        Oceania
# 167                                       Vietnam           Asia
# 168                                       Uruguay  South America
# 169                                  Vatican City         Europe
# 170                                     Hong Kong           Asia
# 171                                       Austria         Europe
# 172                           Antigua and Barbuda  North America
# 173                                  Turkmenistan           Asia
# 174                                    Mozambique         Africa
# 175                                        Panama  North America
# 176                                    Micronesia        Oceania
# 177                                       Ireland         Europe
# 178                                       Curaçao  North America
# 179                                 French Guiana  South America
# 180                                        Norway         Europe
# 181                                 Åland Islands         Europe
# 182                      Central African Republic         Africa
# 183                                  Burkina Faso         Africa
# 184                                       Eritrea         Africa
# 185                                      Tanzania         Africa
# 186                                   South Korea           Asia
# 187                                        Jordan           Asia
# 188                                    Mauritania         Africa
# 189                                     Lithuania         Europe
# 190          United States Minor Outlying Islands        Oceania
# 191                                      Slovakia         Europe
# 192                                        Angola         Africa
# 193                                    Kazakhstan           Asia
# 194                                       Moldova         Europe
# 195                                          Mali         Africa
# 196                              Falkland Islands  South America
# 197                                       Armenia           Asia
# 198                                         Samoa        Oceania
# 199                                        Jersey         Europe
# 200                                         Japan           Asia
# 201                                       Bolivia  South America
# 202                                         Chile  South America
# 203                                 United States  North America
# 204              Saint Vincent and the Grenadines  North America
# 205                                       Bermuda  North America
# 206                                    Seychelles         Africa
# 207                British Indian Ocean Territory           Asia
# 208                                     Guatemala  North America
# 209                                       Ecuador  South America
# 210                                    Martinique  North America
# 211                                    Tajikistan           Asia
# 212                                         Malta         Europe
# 213                                        Gambia         Africa
# 214                                       Nigeria         Africa
# 215                                       Bahamas  North America
# 216                                        Kosovo         Europe
# 217                                        Kuwait           Asia
# 218                                      Maldives           Asia
# 219                                   South Sudan         Africa
# 220                                          Iran           Asia
# 221                                       Albania         Europe
# 222                                        Brazil  South America
# 223                                        Serbia         Europe
# 224                                        Belize  North America
# 225                                       Myanmar           Asia
# 226                                        Bhutan           Asia
# 227                                     Venezuela  South America
# 228                                       Liberia         Africa
# 229                                       Jamaica  North America
# 230                                        Poland         Europe
# 231                                Cayman Islands  North America
# 232                                        Brunei           Asia
# 233                                       Comoros         Africa
# 234                                          Guam        Oceania
# 235                                         Tonga        Oceania
# 236                                      Kiribati        Oceania
# 237                                         Ghana         Africa
# 238                                          Chad         Africa
# 239                                      Zimbabwe         Africa
# 240                                  Saint Martin  North America
# 241                                      Mongolia           Asia
# 242                                      Portugal         Europe
# 243                                American Samoa        Oceania
# 244                         Republic of the Congo         Africa
# 245                                       Belgium         Europe
# 246                                        Israel           Asia
# 247                                   New Zealand        Oceania
# 248                                     Nicaragua  North America
# 249                                      Anguilla  North America
#
#     Country Code (Alpha-3)                   Flag Image URL
# 0                      SGS  https://flagcdn.com/w320/gs.png
# 1                      GRD  https://flagcdn.com/w320/gd.png
# 2                      CHE  https://flagcdn.com/w320/ch.png
# 3                      SLE  https://flagcdn.com/w320/sl.png
# 4                      HUN  https://flagcdn.com/w320/hu.png
# 5                      TWN  https://flagcdn.com/w320/tw.png
# 6                      WLF  https://flagcdn.com/w320/wf.png
# 7                      BRB  https://flagcdn.com/w320/bb.png
# 8                      PCN  https://flagcdn.com/w320/pn.png
# 9                      CIV  https://flagcdn.com/w320/ci.png
# 10                     TUN  https://flagcdn.com/w320/tn.png
# 11                     ITA  https://flagcdn.com/w320/it.png
# 12                     BEN  https://flagcdn.com/w320/bj.png
# 13                     IDN  https://flagcdn.com/w320/id.png
# 14                     CPV  https://flagcdn.com/w320/cv.png
# 15                     KNA  https://flagcdn.com/w320/kn.png
# 16                     LAO  https://flagcdn.com/w320/la.png
# 17                     BES  https://flagcdn.com/w320/bq.png
# 18                     UGA  https://flagcdn.com/w320/ug.png
# 19                     AND  https://flagcdn.com/w320/ad.png
# 20                     BDI  https://flagcdn.com/w320/bi.png
# 21                     ZAF  https://flagcdn.com/w320/za.png
# 22                     FRA  https://flagcdn.com/w320/fr.png
# 23                     LBY  https://flagcdn.com/w320/ly.png
# 24                     MEX  https://flagcdn.com/w320/mx.png
# 25                     GAB  https://flagcdn.com/w320/ga.png
# 26                     MNP  https://flagcdn.com/w320/mp.png
# 27                     MKD  https://flagcdn.com/w320/mk.png
# 28                     CHN  https://flagcdn.com/w320/cn.png
# 29                     YEM  https://flagcdn.com/w320/ye.png
# 30                     BLM  https://flagcdn.com/w320/bl.png
# 31                     GGY  https://flagcdn.com/w320/gg.png
# 32                     SLB  https://flagcdn.com/w320/sb.png
# 33                     SJM  https://flagcdn.com/w320/sj.png
# 34                     FRO  https://flagcdn.com/w320/fo.png
# 35                     UZB  https://flagcdn.com/w320/uz.png
# 36                     EGY  https://flagcdn.com/w320/eg.png
# 37                     SEN  https://flagcdn.com/w320/sn.png
# 38                     LKA  https://flagcdn.com/w320/lk.png
# 39                     PSE  https://flagcdn.com/w320/ps.png
# 40                     BGD  https://flagcdn.com/w320/bd.png
# 41                     PER  https://flagcdn.com/w320/pe.png
# 42                     SGP  https://flagcdn.com/w320/sg.png
# 43                     TUR  https://flagcdn.com/w320/tr.png
# 44                     AFG  https://flagcdn.com/w320/af.png
# 45                     ABW  https://flagcdn.com/w320/aw.png
# 46                     COK  https://flagcdn.com/w320/ck.png
# 47                     GBR  https://flagcdn.com/w320/gb.png
# 48                     ZMB  https://flagcdn.com/w320/zm.png
# 49                     FIN  https://flagcdn.com/w320/fi.png
# 50                     NER  https://flagcdn.com/w320/ne.png
# 51                     CXR  https://flagcdn.com/w320/cx.png
# 52                     TKL  https://flagcdn.com/w320/tk.png
# 53                     GNB  https://flagcdn.com/w320/gw.png
# 54                     AZE  https://flagcdn.com/w320/az.png
# 55                     REU  https://flagcdn.com/w320/re.png
# 56                     DJI  https://flagcdn.com/w320/dj.png
# 57                     PRK  https://flagcdn.com/w320/kp.png
# 58                     MUS  https://flagcdn.com/w320/mu.png
# 59                     MSR  https://flagcdn.com/w320/ms.png
# 60                     VIR  https://flagcdn.com/w320/vi.png
# 61                     COL  https://flagcdn.com/w320/co.png
# 62                     GRC  https://flagcdn.com/w320/gr.png
# 63                     HRV  https://flagcdn.com/w320/hr.png
# 64                     MAR  https://flagcdn.com/w320/ma.png
# 65                     DZA  https://flagcdn.com/w320/dz.png
# 66                     ATA  https://flagcdn.com/w320/aq.png
# 67                     NLD  https://flagcdn.com/w320/nl.png
# 68                     SDN  https://flagcdn.com/w320/sd.png
# 69                     FJI  https://flagcdn.com/w320/fj.png
# 70                     LIE  https://flagcdn.com/w320/li.png
# 71                     NPL  https://flagcdn.com/w320/np.png
# 72                     PRI  https://flagcdn.com/w320/pr.png
# 73                     GEO  https://flagcdn.com/w320/ge.png
# 74                     PAK  https://flagcdn.com/w320/pk.png
# 75                     MCO  https://flagcdn.com/w320/mc.png
# 76                     BWA  https://flagcdn.com/w320/bw.png
# 77                     LBN  https://flagcdn.com/w320/lb.png
# 78                     PNG  https://flagcdn.com/w320/pg.png
# 79                     MYT  https://flagcdn.com/w320/yt.png
# 80                     DOM  https://flagcdn.com/w320/do.png
# 81                     NFK  https://flagcdn.com/w320/nf.png
# 82                     BVT  https://flagcdn.com/w320/bv.png
# 83                     QAT  https://flagcdn.com/w320/qa.png
# 84                     MDG  https://flagcdn.com/w320/mg.png
# 85                     IND  https://flagcdn.com/w320/in.png
# 86                     SYR  https://flagcdn.com/w320/sy.png
# 87                     MNE  https://flagcdn.com/w320/me.png
# 88                     SWZ  https://flagcdn.com/w320/sz.png
# 89                     PRY  https://flagcdn.com/w320/py.png
# 90                     SLV  https://flagcdn.com/w320/sv.png
# 91                     UKR  https://flagcdn.com/w320/ua.png
# 92                     IMN  https://flagcdn.com/w320/im.png
# 93                     NAM  https://flagcdn.com/w320/na.png
# 94                     ARE  https://flagcdn.com/w320/ae.png
# 95                     BGR  https://flagcdn.com/w320/bg.png
# 96                     GRL  https://flagcdn.com/w320/gl.png
# 97                     DEU  https://flagcdn.com/w320/de.png
# 98                     KHM  https://flagcdn.com/w320/kh.png
# 99                     IRQ  https://flagcdn.com/w320/iq.png
# 100                    ATF  https://flagcdn.com/w320/tf.png
# 101                    SWE  https://flagcdn.com/w320/se.png
# 102                    CUB  https://flagcdn.com/w320/cu.png
# 103                    KGZ  https://flagcdn.com/w320/kg.png
# 104                    RUS  https://flagcdn.com/w320/ru.png
# 105                    MYS  https://flagcdn.com/w320/my.png
# 106                    STP  https://flagcdn.com/w320/st.png
# 107                    CYP  https://flagcdn.com/w320/cy.png
# 108                    CAN  https://flagcdn.com/w320/ca.png
# 109                    MWI  https://flagcdn.com/w320/mw.png
# 110                    SAU  https://flagcdn.com/w320/sa.png
# 111                    BIH  https://flagcdn.com/w320/ba.png
# 112                    ETH  https://flagcdn.com/w320/et.png
# 113                    ESP  https://flagcdn.com/w320/es.png
# 114                    SVN  https://flagcdn.com/w320/si.png
# 115                    OMN  https://flagcdn.com/w320/om.png
# 116                    SPM  https://flagcdn.com/w320/pm.png
# 117                    MAC  https://flagcdn.com/w320/mo.png
# 118                    SMR  https://flagcdn.com/w320/sm.png
# 119                    LSO  https://flagcdn.com/w320/ls.png
# 120                    MHL  https://flagcdn.com/w320/mh.png
# 121                    SXM  https://flagcdn.com/w320/sx.png
# 122                    ISL  https://flagcdn.com/w320/is.png
# 123                    LUX  https://flagcdn.com/w320/lu.png
# 124                    ARG  https://flagcdn.com/w320/ar.png
# 125                    TCA  https://flagcdn.com/w320/tc.png
# 126                    NRU  https://flagcdn.com/w320/nr.png
# 127                    CCK  https://flagcdn.com/w320/cc.png
# 128                    ESH  https://flagcdn.com/w320/eh.png
# 129                    DMA  https://flagcdn.com/w320/dm.png
# 130                    CRI  https://flagcdn.com/w320/cr.png
# 131                    AUS  https://flagcdn.com/w320/au.png
# 132                    THA  https://flagcdn.com/w320/th.png
# 133                    HTI  https://flagcdn.com/w320/ht.png
# 134                    TUV  https://flagcdn.com/w320/tv.png
# 135                    HND  https://flagcdn.com/w320/hn.png
# 136                    GNQ  https://flagcdn.com/w320/gq.png
# 137                    LCA  https://flagcdn.com/w320/lc.png
# 138                    PYF  https://flagcdn.com/w320/pf.png
# 139                    BLR  https://flagcdn.com/w320/by.png
# 140                    LVA  https://flagcdn.com/w320/lv.png
# 141                    PLW  https://flagcdn.com/w320/pw.png
# 142                    GLP  https://flagcdn.com/w320/gp.png
# 143                    PHL  https://flagcdn.com/w320/ph.png
# 144                    GIB  https://flagcdn.com/w320/gi.png
# 145                    DNK  https://flagcdn.com/w320/dk.png
# 146                    CMR  https://flagcdn.com/w320/cm.png
# 147                    GIN  https://flagcdn.com/w320/gn.png
# 148                    BHR  https://flagcdn.com/w320/bh.png
# 149                    SUR  https://flagcdn.com/w320/sr.png
# 150                    COD  https://flagcdn.com/w320/cd.png
# 151                    SOM  https://flagcdn.com/w320/so.png
# 152                    CZE  https://flagcdn.com/w320/cz.png
# 153                    NCL  https://flagcdn.com/w320/nc.png
# 154                    VUT  https://flagcdn.com/w320/vu.png
# 155                    SHN  https://flagcdn.com/w320/sh.png
# 156                    TGO  https://flagcdn.com/w320/tg.png
# 157                    VGB  https://flagcdn.com/w320/vg.png
# 158                    KEN  https://flagcdn.com/w320/ke.png
# 159                    NIU  https://flagcdn.com/w320/nu.png
# 160                    HMD  https://flagcdn.com/w320/hm.png
# 161                    RWA  https://flagcdn.com/w320/rw.png
# 162                    EST  https://flagcdn.com/w320/ee.png
# 163                    ROU  https://flagcdn.com/w320/ro.png
# 164                    TTO  https://flagcdn.com/w320/tt.png
# 165                    GUY  https://flagcdn.com/w320/gy.png
# 166                    TLS  https://flagcdn.com/w320/tl.png
# 167                    VNM  https://flagcdn.com/w320/vn.png
# 168                    URY  https://flagcdn.com/w320/uy.png
# 169                    VAT  https://flagcdn.com/w320/va.png
# 170                    HKG  https://flagcdn.com/w320/hk.png
# 171                    AUT  https://flagcdn.com/w320/at.png
# 172                    ATG  https://flagcdn.com/w320/ag.png
# 173                    TKM  https://flagcdn.com/w320/tm.png
# 174                    MOZ  https://flagcdn.com/w320/mz.png
# 175                    PAN  https://flagcdn.com/w320/pa.png
# 176                    FSM  https://flagcdn.com/w320/fm.png
# 177                    IRL  https://flagcdn.com/w320/ie.png
# 178                    CUW  https://flagcdn.com/w320/cw.png
# 179                    GUF  https://flagcdn.com/w320/gf.png
# 180                    NOR  https://flagcdn.com/w320/no.png
# 181                    ALA  https://flagcdn.com/w320/ax.png
# 182                    CAF  https://flagcdn.com/w320/cf.png
# 183                    BFA  https://flagcdn.com/w320/bf.png
# 184                    ERI  https://flagcdn.com/w320/er.png
# 185                    TZA  https://flagcdn.com/w320/tz.png
# 186                    KOR  https://flagcdn.com/w320/kr.png
# 187                    JOR  https://flagcdn.com/w320/jo.png
# 188                    MRT  https://flagcdn.com/w320/mr.png
# 189                    LTU  https://flagcdn.com/w320/lt.png
# 190                    UMI  https://flagcdn.com/w320/um.png
# 191                    SVK  https://flagcdn.com/w320/sk.png
# 192                    AGO  https://flagcdn.com/w320/ao.png
# 193                    KAZ  https://flagcdn.com/w320/kz.png
# 194                    MDA  https://flagcdn.com/w320/md.png
# 195                    MLI  https://flagcdn.com/w320/ml.png
# 196                    FLK  https://flagcdn.com/w320/fk.png
# 197                    ARM  https://flagcdn.com/w320/am.png
# 198                    WSM  https://flagcdn.com/w320/ws.png
# 199                    JEY  https://flagcdn.com/w320/je.png
# 200                    JPN  https://flagcdn.com/w320/jp.png
# 201                    BOL  https://flagcdn.com/w320/bo.png
# 202                    CHL  https://flagcdn.com/w320/cl.png
# 203                    USA  https://flagcdn.com/w320/us.png
# 204                    VCT  https://flagcdn.com/w320/vc.png
# 205                    BMU  https://flagcdn.com/w320/bm.png
# 206                    SYC  https://flagcdn.com/w320/sc.png
# 207                    IOT  https://flagcdn.com/w320/io.png
# 208                    GTM  https://flagcdn.com/w320/gt.png
# 209                    ECU  https://flagcdn.com/w320/ec.png
# 210                    MTQ  https://flagcdn.com/w320/mq.png
# 211                    TJK  https://flagcdn.com/w320/tj.png
# 212                    MLT  https://flagcdn.com/w320/mt.png
# 213                    GMB  https://flagcdn.com/w320/gm.png
# 214                    NGA  https://flagcdn.com/w320/ng.png
# 215                    BHS  https://flagcdn.com/w320/bs.png
# 216                    UNK  https://flagcdn.com/w320/xk.png
# 217                    KWT  https://flagcdn.com/w320/kw.png
# 218                    MDV  https://flagcdn.com/w320/mv.png
# 219                    SSD  https://flagcdn.com/w320/ss.png
# 220                    IRN  https://flagcdn.com/w320/ir.png
# 221                    ALB  https://flagcdn.com/w320/al.png
# 222                    BRA  https://flagcdn.com/w320/br.png
# 223                    SRB  https://flagcdn.com/w320/rs.png
# 224                    BLZ  https://flagcdn.com/w320/bz.png
# 225                    MMR  https://flagcdn.com/w320/mm.png
# 226                    BTN  https://flagcdn.com/w320/bt.png
# 227                    VEN  https://flagcdn.com/w320/ve.png
# 228                    LBR  https://flagcdn.com/w320/lr.png
# 229                    JAM  https://flagcdn.com/w320/jm.png
# 230                    POL  https://flagcdn.com/w320/pl.png
# 231                    CYM  https://flagcdn.com/w320/ky.png
# 232                    BRN  https://flagcdn.com/w320/bn.png
# 233                    COM  https://flagcdn.com/w320/km.png
# 234                    GUM  https://flagcdn.com/w320/gu.png
# 235                    TON  https://flagcdn.com/w320/to.png
# 236                    KIR  https://flagcdn.com/w320/ki.png
# 237                    GHA  https://flagcdn.com/w320/gh.png
# 238                    TCD  https://flagcdn.com/w320/td.png
# 239                    ZWE  https://flagcdn.com/w320/zw.png
# 240                    MAF  https://flagcdn.com/w320/mf.png
# 241                    MNG  https://flagcdn.com/w320/mn.png
# 242                    PRT  https://flagcdn.com/w320/pt.png
# 243                    ASM  https://flagcdn.com/w320/as.png
# 244                    COG  https://flagcdn.com/w320/cg.png
# 245                    BEL  https://flagcdn.com/w320/be.png
# 246                    ISR  https://flagcdn.com/w320/il.png
# 247                    NZL  https://flagcdn.com/w320/nz.png
# 248                    NIC  https://flagcdn.com/w320/ni.png
# 249                    AIA  https://flagcdn.com/w320/ai.png
