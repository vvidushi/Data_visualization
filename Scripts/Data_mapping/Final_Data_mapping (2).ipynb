# %% [markdown]
# # Display all rows where data is missing for the specified columns

# %%
import pandas as pd

teams_df = pd.read_csv("/Users/vidushi/Documents/Data_Visualization/datasets/olympics/teams.csv")
specified_columns = ['events', 'athletes', 'coaches', 'athletes_codes', 'num_athletes', 'coaches_codes', 'num_coaches']
missing_data_columns = teams_df[specified_columns].isnull().sum()
missing_data_columns = missing_data_columns[missing_data_columns > 0]  # Only keep columns with missing values
missing_data_columns_list = missing_data_columns.index.tolist()  # Convert to list

print("Columns with Missing Data:")
print(missing_data_columns)

for column in missing_data_columns_list:
    print(f"\nRows with Missing Data in Column '{column}':")
    teams_df
# Out:
# Columns with Missing Data:
# events             321
# athletes             3
# coaches           1452
# athletes_codes       3
# num_athletes         3
# coaches_codes     1452
# num_coaches       1452
# dtype: int64
#
# Rows with Missing Data in Column 'events':
#
# Rows with Missing Data in Column 'athletes':
#
# Rows with Missing Data in Column 'coaches':
#
# Rows with Missing Data in Column 'athletes_codes':
#
# Rows with Missing Data in Column 'num_athletes':
#
# Rows with Missing Data in Column 'coaches_codes':
#
# Rows with Missing Data in Column 'num_coaches':

# %% [markdown]
# #  Dynamically read dictionary of DataFrames and Display basic information about each DataFrame

# %%
import pandas as pd
import os
import warnings
import matplotlib.pyplot as plt
import seaborn as sns
warnings.filterwarnings('ignore')  # Suppress warnings for cleaner output

# File paths
base_path = "/Users/vidushi/Documents/Data_Visualization/datasets/olympics"
files = ["teams.csv", "medallists.csv", "medals.csv", "medals_total.csv", 
         "athletes.csv", "coaches.csv", "events.csv"]

# Function to safely read CSV files
def safe_read_csv(file_path):
    try:
        return pd.read_csv(file_path)
    except FileNotFoundError:
        print(f"Warning: File not found: {file_path}")
        return None

dataframes = {}
for file in files:
    file_path = os.path.join(base_path, file)
    df = safe_read_csv(file_path)
    if df is not None:
        dataframes[file.replace('.csv', '')] = df

print(f"Successfully loaded {len(dataframes)} out of {len(files)} files.")


for name, df in dataframes.items():
    print(f"\n{name} shape: {df.shape}")
    print(f"{name} columns: {df.columns.tolist()}")
    display(df.head(2))  # Show first 2 rows of each DataFrame
# Out:
# Successfully loaded 7 out of 7 files.
#
# teams shape: (1698, 16)
# teams columns: ['code', 'current', 'team', 'team_gender', 'country_code', 'country', 'country_long', 'discipline', 'disciplines_code', 'events', 'athletes', 'coaches', 'athletes_codes', 'num_athletes', 'coaches_codes', 'num_coaches']
#                 code  current                        team team_gender  \
# 0  ARCMTEAM3---CHN01     True  People's Republic of China           M
# 1  ARCMTEAM3---COL01     True                    Colombia           M
#
#   country_code   country                country_long discipline  \
# 0          CHN     China  People's Republic of China    Archery
# 1          COL  Colombia                    Colombia    Archery
#
#   disciplines_code      events  \
# 0              ARC  Men's Team
# 1              ARC  Men's Team
#
#                                             athletes coaches  \
# 0        ['KAO Wenchao', 'LI Zhongyuan', 'WANG Yan']     NaN
# 1  ['ARCILA Santiago', 'ENRIQUEZ Jorge', 'HERNAND...     NaN
#
#                       athletes_codes  num_athletes coaches_codes  num_coaches
# 0  ['1913366', '1913367', '1913369']           3.0           NaN          NaN
# 1  ['1935642', '1543412', '1935644']           3.0           NaN          NaN
# medallists shape: (2315, 21)
# medallists columns: ['medal_date', 'medal_type', 'medal_code', 'name', 'gender', 'country_code', 'country', 'country_long', 'nationality_code', 'nationality', 'nationality_long', 'team', 'team_gender', 'discipline', 'event', 'event_type', 'url_event', 'birth_date', 'code_athlete', 'code_team', 'is_medallist']
#    medal_date    medal_type  medal_code             name gender country_code  \
# 0  2024-07-27    Gold Medal         1.0  EVENEPOEL Remco   Male          BEL
# 1  2024-07-27  Silver Medal         2.0    GANNA Filippo   Male          ITA
#
#    country country_long nationality_code nationality  ... team team_gender  \
# 0  Belgium      Belgium              BEL     Belgium  ...  NaN         NaN
# 1    Italy        Italy              ITA       Italy  ...  NaN         NaN
#
#      discipline                        event event_type  \
# 0  Cycling Road  Men's Individual Time Trial        ATH
# 1  Cycling Road  Men's Individual Time Trial        ATH
#
#                                            url_event  birth_date code_athlete  \
# 0  /en/paris-2024/results/cycling-road/men-s-indi...  2000-01-25      1903136
# 1  /en/paris-2024/results/cycling-road/men-s-indi...  1996-07-25      1923520
#
#    code_team is_medallist
# 0        NaN         True
# 1        NaN         True
#
# [2 rows x 21 columns]
# medals shape: (1044, 13)
# medals columns: ['medal_type', 'medal_code', 'medal_date', 'name', 'gender', 'discipline', 'event', 'event_type', 'url_event', 'code', 'country_code', 'country', 'country_long']
#      medal_type  medal_code  medal_date             name gender    discipline  \
# 0    Gold Medal         1.0  2024-07-27  Remco EVENEPOEL      M  Cycling Road
# 1  Silver Medal         2.0  2024-07-27    Filippo GANNA      M  Cycling Road
#
#                          event event_type  \
# 0  Men's Individual Time Trial        ATH
# 1  Men's Individual Time Trial        ATH
#
#                                            url_event     code country_code  \
# 0  /en/paris-2024/results/cycling-road/men-s-indi...  1903136          BEL
# 1  /en/paris-2024/results/cycling-road/men-s-indi...  1923520          ITA
#
#    country country_long
# 0  Belgium      Belgium
# 1    Italy        Italy
# medals_total shape: (92, 7)
# medals_total columns: ['country_code', 'country', 'country_long', 'Gold Medal', 'Silver Medal', 'Bronze Medal', 'Total']
#   country_code        country                country_long  Gold Medal  \
# 0          USA  United States    United States of America          40
# 1          CHN          China  People's Republic of China          40
#
#    Silver Medal  Bronze Medal  Total
# 0            44            42    126
# 1            27            24     91
# athletes shape: (11113, 36)
# athletes columns: ['code', 'current', 'name', 'name_short', 'name_tv', 'gender', 'function', 'country_code', 'country', 'country_long', 'nationality', 'nationality_long', 'nationality_code', 'height', 'weight', 'disciplines', 'events', 'birth_date', 'birth_place', 'birth_country', 'residence_place', 'residence_country', 'nickname', 'hobbies', 'occupation', 'education', 'family', 'lang', 'coach', 'reason', 'hero', 'influence', 'philosophy', 'sporting_relatives', 'ritual', 'other_sports']
#       code  current              name    name_short           name_tv gender  \
# 0  1532872     True  ALEKSANYAN Artur  ALEKSANYAN A  Artur ALEKSANYAN   Male
# 1  1532873     True    AMOYAN Malkhas      AMOYAN M    Malkhas AMOYAN   Male
#
#   function country_code  country country_long  ...                     family  \
# 0  Athlete          ARM  Armenia      Armenia  ...  Father, Gevorg Aleksanyan
# 1  Athlete          ARM  Armenia      Armenia  ...                        NaN
#
#                          lang                            coach  \
# 0  Armenian, English, Russian  Gevorg Aleksanyan (ARM), father
# 1                    Armenian                              NaN
#
#                                               reason  \
# 0  He followed his father and his uncle into the ...
# 1                                                NaN
#
#                                                 hero  \
# 0  Footballer Zinedine Zidane (FRA), World Cup wi...
# 1                                                NaN
#
#                        influence  \
# 0  His father, Gevorg Aleksanyan
# 1                            NaN
#
#                                           philosophy  \
# 0  "Wrestling is my life." (mediamax.am. 18 May 2...
# 1  "To become a good athlete, you first have to b...
#
#                                   sporting_relatives ritual other_sports
# 0                                                NaN    NaN          NaN
# 1  Uncle, Roman Amoyan (wrestling), 2008 Olympic ...    NaN          NaN
#
# [2 rows x 36 columns]
# coaches shape: (974, 12)
# coaches columns: ['code', 'current', 'name', 'gender', 'function', 'category', 'country_code', 'country', 'country_long', 'disciplines', 'events', 'birth_date']
#       code  current              name  gender    function category  \
# 0  1533246     True    PEDRERO Ofelia  Female       Coach        C
# 1  1535775     True  RADHI SHENAISHIL    Male  Head Coach        C
#
#   country_code country country_long        disciplines events  birth_date
# 0          MEX  Mexico       Mexico  Artistic Swimming   Team  1988-03-28
# 1          IRQ    Iraq         Iraq           Football    Men  1965-07-01
# events shape: (329, 5)
# events columns: ['event', 'tag', 'sport', 'sport_code', 'sport_url']
#                 event      tag    sport sport_code  \
# 0    Men's Individual  archery  Archery        ARC
# 1  Women's Individual  archery  Archery        ARC
#
#                                            sport_url
# 0  https://olympics.com/en/paris-2024/sports/archery
# 1  https://olympics.com/en/paris-2024/sports/archery

# %% [markdown]
# # Function to identify common columns between two DataFrames

# %%
def find_common_columns(df1, df2):
    return list(set(df1.columns) & set(df2.columns))

# Main table
teams_df = dataframes.get('teams')
if teams_df is None:
    print("Main table (teams.csv) is missing. Cannot proceed with column mapping.")
else:
    mapping_results = {}
    for name, df in dataframes.items():
        if name != 'teams':
            common_cols = find_common_columns(teams_df, df)
            mapping_results[name] = common_cols
            print(f"\nCommon columns between teams and {name}:")
            print(common_cols)
# Out:
# Common columns between teams and medallists:
# ['country_long', 'country', 'country_code', 'team_gender', 'discipline', 'team']
#
# Common columns between teams and medals:
# ['country_long', 'country', 'country_code', 'code', 'discipline']
#
# Common columns between teams and medals_total:
# ['country_code', 'country_long', 'country']
#
# Common columns between teams and athletes:
# ['country_long', 'country', 'country_code', 'code', 'current', 'events']
#
# Common columns between teams and coaches:
# ['country_long', 'country', 'country_code', 'code', 'current', 'events']
#
# Common columns between teams and events:
# []

# %% [markdown]
# # Function to check value consistency between two DataFrames for common columns

# %%
def check_value_consistency(df1, df1_name, df2, df2_name, common_cols):
    results = {}
    for col in common_cols:
        # Get unique values from both DataFrames for the column
        values_df1 = set(df1[col].dropna().unique())
        values_df2 = set(df2[col].dropna().unique())
        
        # Check if all values in df1 are present in df2
        missing_in_df2 = values_df1 - values_df2
        # Check if all values in df2 are present in df1
        missing_in_df1 = values_df2 - values_df1
        
        # Calculate percentage of matching values
        total_unique_values = len(values_df1.union(values_df2))
        if total_unique_values > 0:
            matching_values = len(values_df1.intersection(values_df2))
            match_percentage = (matching_values / total_unique_values) * 100
        else:
            match_percentage = 100.0  # Both sets empty = 100% match
        
        results[col] = {
            'match_percentage': match_percentage,
            'unique_in_' + df1_name: list(missing_in_df2)[:5] if len(missing_in_df2) > 0 else [],
            'count_unique_in_' + df1_name: len(missing_in_df2),
            'unique_in_' + df2_name: list(missing_in_df1)[:5] if len(missing_in_df1) > 0 else [],
            'count_unique_in_' + df2_name: len(missing_in_df1)
        }
    
    return results

# %% [markdown]
# # Check value consistency for common columns between teams and other tables

# %%
if teams_df is not None:
    consistency_results = {}
    for name, df in dataframes.items():
        if name != 'teams':
            common_cols = mapping_results[name]
            if common_cols:
                print(f"\nValue consistency check between teams and {name}:")
                table_results = check_value_consistency(teams_df, 'teams', df, name, common_cols)
                consistency_results[name] = table_results
                
                for col, result in table_results.items():
                    print(f"  Column '{col}':")
                    print(f"    Match percentage: {result['match_percentage']:.2f}%")
                    print(f"    Values unique to teams (count): {result['count_unique_in_teams']}")
                    if result['unique_in_teams']:
                        print(f"    Examples unique to teams: {result['unique_in_teams']}")
                    print(f"    Values unique to {name} (count): {result['count_unique_in_' + name]}")
                    if result['unique_in_' + name]:
                        print(f"    Examples unique to {name}: {result['unique_in_' + name]}")
# Out:
# Value consistency check between teams and medallists:
#   Column 'country_long':
#     Match percentage: 63.33%
#     Values unique to teams (count): 28
#     Examples unique to teams: ['Iraq', 'Montenegro', 'Samoa', 'Estonia', 'South Sudan']
#     Values unique to medallists (count): 16
#     Examples unique to medallists: ['Philippines', 'Ethiopia', 'Kyrgyzstan', 'Cyprus', 'Jordan']
#   Column 'discipline':
#     Match percentage: 62.22%
#     Values unique to teams (count): 0
#     Values unique to medallists (count): 17
#     Examples unique to medallists: ['Cycling Mountain Bike', 'Cycling BMX Racing', 'Breaking', 'Cycling Road', 'Cycling BMX Freestyle']
#   Column 'country_code':
#     Match percentage: 63.33%
#     Values unique to teams (count): 28
#     Examples unique to teams: ['EST', 'FRG', 'FIN', 'SSD', 'GDR']
#     Values unique to medallists (count): 16
#     Examples unique to medallists: ['ARM', 'CPV', 'LCA', 'GRN', 'DMA']
#   Column 'team_gender':
#     Match percentage: 100.00%
#     Values unique to teams (count): 0
#     Values unique to medallists (count): 0
#   Column 'team':
#     Match percentage: 20.45%
#     Values unique to teams (count): 393
#     Examples unique to teams: ['ROEHLINGS Lena / JAGSCH Pauline', 'FRUERGAARD Maiken / THYGESEN Sara', 'LINKE C / FEIGE S', 'Montenegro', 'DONG Adam / YAKURA Nyl']
#     Values unique to medallists (count): 0
#   Column 'country':
#     Match percentage: 63.33%
#     Values unique to teams (count): 28
#     Examples unique to teams: ['Iraq', 'FRG', 'German Dem. Republic', 'Montenegro', 'Samoa']
#     Values unique to medallists (count): 16
#     Examples unique to medallists: ['Philippines', 'Ethiopia', 'Kyrgyzstan', 'Cyprus', 'Jordan']
#
# Value consistency check between teams and medals:
#   Column 'country_long':
#     Match percentage: 63.33%
#     Values unique to teams (count): 28
#     Examples unique to teams: ['Iraq', 'Montenegro', 'Samoa', 'Estonia', 'South Sudan']
#     Values unique to medals (count): 16
#     Examples unique to medals: ['Philippines', 'Ethiopia', 'Kyrgyzstan', 'Cyprus', 'Jordan']
#   Column 'discipline':
#     Match percentage: 62.22%
#     Values unique to teams (count): 0
#     Values unique to medals (count): 17
#     Examples unique to medals: ['Cycling Mountain Bike', 'Cycling BMX Racing', 'Breaking', 'Cycling Road', 'Cycling BMX Freestyle']
#   Column 'country_code':
#     Match percentage: 63.33%
#     Values unique to teams (count): 28
#     Examples unique to teams: ['EST', 'FRG', 'FIN', 'SSD', 'GDR']
#     Values unique to medals (count): 16
#     Examples unique to medals: ['ARM', 'CPV', 'LCA', 'GRN', 'DMA']
#   Column 'code':
#     Match percentage: 11.80%
#     Values unique to teams (count): 1414
#     Examples unique to teams: ['ROWMSCULL2-LJPN01', 'T246191162159', 'ARCMTEAM3---CHN01', 'FBLMTEAM11--ARG01', 'VBVMTEAM2---NED02']
#     Values unique to medals (count): 708
#     Examples unique to medals: ['1878353', '1891323', '1920183', '3429662', '1904040']
#   Column 'country':
#     Match percentage: 63.33%
#     Values unique to teams (count): 28
#     Examples unique to teams: ['Iraq', 'FRG', 'German Dem. Republic', 'Montenegro', 'Samoa']
#     Values unique to medals (count): 16
#     Examples unique to medals: ['Philippines', 'Ethiopia', 'Kyrgyzstan', 'Cyprus', 'Jordan']
#
# Value consistency check between teams and medals_total:
#   Column 'country_long':
#     Match percentage: 63.33%
#     Values unique to teams (count): 28
#     Examples unique to teams: ['Iraq', 'Montenegro', 'Samoa', 'Estonia', 'South Sudan']
#     Values unique to medals_total (count): 16
#     Examples unique to medals_total: ['Philippines', 'Ethiopia', 'Kyrgyzstan', 'Cyprus', 'Jordan']
#   Column 'country':
#     Match percentage: 63.33%
#     Values unique to teams (count): 28
#     Examples unique to teams: ['Iraq', 'FRG', 'German Dem. Republic', 'Montenegro', 'Samoa']
#     Values unique to medals_total (count): 16
#     Examples unique to medals_total: ['Philippines', 'Ethiopia', 'Kyrgyzstan', 'Cyprus', 'Jordan']
#   Column 'country_code':
#     Match percentage: 63.33%
#     Values unique to teams (count): 28
#     Examples unique to teams: ['EST', 'FRG', 'FIN', 'SSD', 'GDR']
#     Values unique to medals_total (count): 16
#     Examples unique to medals_total: ['ARM', 'CPV', 'LCA', 'GRN', 'DMA']
#
# Value consistency check between teams and athletes:
#   Column 'country_long':
#     Match percentage: 46.92%
#     Values unique to teams (count): 5
#     Examples unique to teams: ['German Democratic Republic', 'USSR', 'Federal Republic of Germany', 'Russian Federation', 'Unified Team']
#     Values unique to athletes (count): 107
#     Examples unique to athletes: ['Luxembourg', 'Marshall Islands', 'Sri Lanka', 'Namibia', 'Aruba']
#   Column 'country_code':
#     Match percentage: 46.92%
#     Values unique to teams (count): 5
#     Examples unique to teams: ['FRG', 'RUS', 'URS', 'GDR', 'EUN']
#     Values unique to athletes (count): 107
#     Examples unique to athletes: ['HON', 'MOZ', 'ISV', 'PLW', 'ALB']
#   Column 'events':
#     Match percentage: 0.00%
#     Values unique to teams (count): 69
#     Examples unique to teams: ["Women's 4 x 200m Freestyle Relay", 'Group All-Around', 'Team', "Men's 4 x 100m Medley Relay", "Women's Team"]
#     Values unique to athletes (count): 643
#     Examples unique to athletes: ['["Women\'s Freestyle 76kg"]', "['Women -52 kg', 'Mixed Team']", '["Women\'s Road Race", "Women\'s Individual Time Trial", "Women\'s Team Pursuit"]', '["Women\'s 10km", "Women\'s 1500m Freestyle", "Women\'s 400m Individual Medley"]', "['Women']"]
#   Column 'code':
#     Match percentage: 0.00%
#     Values unique to teams (count): 1698
#     Examples unique to teams: ['ATHW4X100M--GER01', 'BDMXDOUBLES-CHN02', 'ROWMSCULL2-LJPN01', 'T246191162159', 'ARCMTEAM3---CHN01']
#     Values unique to athletes (count): 11113
#     Examples unique to athletes: [np.int64(1933313), np.int64(1933316), np.int64(1933320), np.int64(1540108), np.int64(1933327)]
#   Column 'current':
#     Match percentage: 100.00%
#     Values unique to teams (count): 0
#     Values unique to athletes (count): 0
#   Column 'country':
#     Match percentage: 46.92%
#     Values unique to teams (count): 5
#     Examples unique to teams: ['FRG', 'German Dem. Republic', 'USSR', 'Russian Federation', 'Unified Team']
#     Values unique to athletes (count): 107
#     Examples unique to athletes: ['Luxembourg', 'Marshall Islands', 'Sri Lanka', 'Lao PDR', 'Namibia']
#
# Value consistency check between teams and coaches:
#   Column 'country_long':
#     Match percentage: 60.32%
#     Values unique to teams (count): 28
#     Examples unique to teams: ['Botswana', 'Estonia', 'Unified Team', 'Malaysia', 'Pakistan']
#     Values unique to coaches (count): 22
#     Examples unique to coaches: ['North Macedonia', 'Niger', 'Burkina Faso', 'Panama', 'Lesotho']
#   Column 'country_code':
#     Match percentage: 60.32%
#     Values unique to teams (count): 28
#     Examples unique to teams: ['EST', 'FRG', 'FIN', 'GDR', 'MGL']
#     Values unique to coaches (count): 22
#     Examples unique to coaches: ['HAI', 'LAO', 'SUR', 'SEN', 'ARM']
#   Column 'events':
#     Match percentage: 5.80%
#     Values unique to teams (count): 65
#     Examples unique to teams: ["Women's 4 x 200m Freestyle Relay", 'Group All-Around', "Men's 4 x 100m Medley Relay", "Men's Kayak Double 500m", "Women's Quadruple Sculls"]
#     Values unique to coaches (count): 0
#   Column 'code':
#     Match percentage: 0.00%
#     Values unique to teams (count): 1698
#     Examples unique to teams: ['ATHW4X100M--GER01', 'BDMXDOUBLES-CHN02', 'ROWMSCULL2-LJPN01', 'T246191162159', 'ARCMTEAM3---CHN01']
#     Values unique to coaches (count): 974
#     Examples unique to coaches: [np.int64(4653058), np.int64(1927174), np.int64(1914903), np.int64(1566746), np.int64(1566749)]
#   Column 'current':
#     Match percentage: 50.00%
#     Values unique to teams (count): 1
#     Examples unique to teams: [np.False_]
#     Values unique to coaches (count): 0
#   Column 'country':
#     Match percentage: 60.32%
#     Values unique to teams (count): 28
#     Examples unique to teams: ['FRG', 'German Dem. Republic', 'Botswana', 'Estonia', 'Unified Team']
#     Values unique to coaches (count): 22
#     Examples unique to coaches: ['Lao PDR', 'North Macedonia', 'Niger', 'Burkina Faso', 'Panama']

# %% [markdown]
# # Create a heatmap to visualize match percentages

# %%
if 'consistency_results' in locals() and consistency_results:
    match_data = {}
    for table_name, table_results in consistency_results.items():
        match_data[table_name] = {col: result['match_percentage'] for col, result in table_results.items()}
    
    # Convert to DataFrame for visualization
    match_df = pd.DataFrame(match_data)
    
    # Plot heatmap
    plt.figure(figsize=(10, 8))
    sns.heatmap(match_df, annot=True, cmap='YlGnBu', vmin=0, vmax=100)
    plt.title('Value Consistency (%) between teams.csv and Other Tables')
    plt.ylabel('Common Column')
    plt.xlabel('Table')
    plt.tight_layout()
    plt.show()

# %% [markdown]
# # E-R Diagram observation

# %%
import pandas as pd
import glob
import os
import numpy as np
import matplotlib.pyplot as plt
import networkx as nx
from itertools import combinations

# Set the directory path
csv_dir = '/Users/vidushi/PycharmProjects/Data_visualization/Files/Cleaned'

# Find all CSV files in the directory
csv_files = glob.glob(os.path.join(csv_dir, '*.csv'))

# Read each CSV into a DataFrame and store in a dictionary
dataframes = {}
for file in csv_files:
    # Extract just the filename without extension
    df_name = os.path.splitext(os.path.basename(file))[0]
    try:
        df = pd.read_csv(file)
        dataframes[df_name] = df
        print(f"Loaded: {df_name} ({df.shape[0]} rows, {df.shape[1]} columns)")
    except Exception as e:
        print(f"Error loading {df_name}: {e}")

# Find all pairs and their common columns
common_columns = {}
for df1_name, df2_name in combinations(dataframes.keys(), 2):
    df1 = dataframes[df1_name]
    df2 = dataframes[df2_name]
    
    # Find common columns
    common = list(set(df1.columns) & set(df2.columns))
    
    # Only store pairs that have common columns
    if common:
        pair_key = (df1_name, df2_name)
        common_columns[pair_key] = common
        
        # Print detailed information about the relationship
        print(f"\nRelationship: {df1_name} <-> {df2_name}")
        print(f"Common columns: {common}")
        
        # For each common column, check how many values match between datasets
        for col in common:
            if col in df1.columns and col in df2.columns:
                df1_values = set(df1[col].dropna().astype(str))
                df2_values = set(df2[col].dropna().astype(str))
                
                # Calculate match percentage
                if df1_values:
                    match_percentage = len(df1_values.intersection(df2_values)) / len(df1_values) * 100
                    print(f"  - {col}: {match_percentage:.1f}% match ({len(df1_values.intersection(df2_values))} matching values)")

# Summary of all relationships
print("\n--- SUMMARY OF RELATIONSHIPS ---")
for (df1, df2), columns in common_columns.items():
    print(f"{df1} <-> {df2}: {', '.join(columns)}")
# Out:
# Loaded: medalstotal_data (92 rows, 6 columns)
# Loaded: cleaned_teams (1698 rows, 13 columns)
# Loaded: medallists_data (2315 rows, 16 columns)
# Loaded: events (329 rows, 5 columns)
# Loaded: athlete_data (11113 rows, 13 columns)
# Loaded: medals_data (1044 rows, 11 columns)
# Loaded: countries_with_flags (250 rows, 4 columns)
# Loaded: Historical_Medal (24012 rows, 11 columns)
#
# Relationship: medalstotal_data <-> cleaned_teams
# Common columns: ['country_code', 'country']
#   - country_code: 82.6% match (76 matching values)
#   - country: 76.1% match (70 matching values)
#
# Relationship: medalstotal_data <-> medallists_data
# Common columns: ['country_code', 'country']
#   - country_code: 100.0% match (92 matching values)
#   - country: 100.0% match (92 matching values)
#
# Relationship: medalstotal_data <-> athlete_data
# Common columns: ['country_code']
#   - country_code: 100.0% match (92 matching values)
#
# Relationship: medalstotal_data <-> medals_data
# Common columns: ['country_code', 'country']
#   - country_code: 100.0% match (92 matching values)
#   - country: 100.0% match (92 matching values)
#
# Relationship: medalstotal_data <-> Historical_Medal
# Common columns: ['country_code', 'country']
#   - country_code: 100.0% match (92 matching values)
#   - country: 100.0% match (92 matching values)
#
# Relationship: cleaned_teams <-> medallists_data
# Common columns: ['country_code', 'team', 'team_gender', 'country', 'discipline']
#   - country_code: 73.1% match (76 matching values)
#   - team: 20.4% match (101 matching values)
#   - team_gender: 100.0% match (4 matching values)
#   - country: 67.3% match (70 matching values)
#   - discipline: 100.0% match (28 matching values)
#
# Relationship: cleaned_teams <-> events
# Common columns: ['events']
#   - events: 98.6% match (69 matching values)
#
# Relationship: cleaned_teams <-> athlete_data
# Common columns: ['country_code', 'team_gender', 'events', 'discipline', 'current', 'code']
#   - country_code: 95.2% match (99 matching values)
#   - team_gender: 0.0% match (0 matching values)
#   - events: 18.6% match (13 matching values)
#   - discipline: 100.0% match (28 matching values)
#   - current: 100.0% match (2 matching values)
#   - code: 0.0% match (0 matching values)
#
# Relationship: cleaned_teams <-> medals_data
# Common columns: ['country_code', 'country', 'code', 'discipline']
#   - country_code: 73.1% match (76 matching values)
#   - country: 67.3% match (70 matching values)
#   - code: 16.7% match (284 matching values)
#   - discipline: 100.0% match (28 matching values)
#
# Relationship: cleaned_teams <-> Historical_Medal
# Common columns: ['country_code', 'country', 'discipline']
#   - country_code: 95.2% match (99 matching values)
#   - country: 85.6% match (89 matching values)
#   - discipline: 100.0% match (28 matching values)
#
# Relationship: medallists_data <-> athlete_data
# Common columns: ['country_code', 'team_gender', 'discipline']
#   - country_code: 100.0% match (92 matching values)
#   - team_gender: 0.0% match (0 matching values)
#   - discipline: 100.0% match (45 matching values)
#
# Relationship: medallists_data <-> medals_data
# Common columns: ['country_code', 'medal_date', 'gender', 'country', 'medal_code', 'discipline', 'event_type', 'name', 'event', 'medal_type']
#   - country_code: 100.0% match (92 matching values)
#   - medal_date: 100.0% match (16 matching values)
#   - gender: 0.0% match (0 matching values)
#   - country: 100.0% match (92 matching values)
#   - medal_code: 100.0% match (3 matching values)
#   - discipline: 100.0% match (45 matching values)
#   - event_type: 100.0% match (6 matching values)
#   - name: 0.0% match (1 matching values)
#   - event: 100.0% match (288 matching values)
#   - medal_type: 100.0% match (3 matching values)
#
# Relationship: medallists_data <-> Historical_Medal
# Common columns: ['country_code', 'country', 'discipline', 'event_type', 'name', 'event', 'medal_type']
#   - country_code: 100.0% match (92 matching values)
#   - country: 100.0% match (92 matching values)
#   - discipline: 100.0% match (45 matching values)
#   - event_type: 0.0% match (0 matching values)
#   - name: 25.2% match (518 matching values)
#   - event: 5.2% match (15 matching values)
#   - medal_type: 0.0% match (0 matching values)
#
# Relationship: events <-> athlete_data
# Common columns: ['events']
#   - events: 18.4% match (53 matching values)
#
# Relationship: athlete_data <-> medals_data
# Common columns: ['country_code', 'code', 'discipline']
#   - country_code: 44.7% match (92 matching values)
#   - code: 6.4% match (708 matching values)
#   - discipline: 90.0% match (45 matching values)
#
# Relationship: athlete_data <-> Historical_Medal
# Common columns: ['country_code', 'discipline']
#   - country_code: 68.9% match (142 matching values)
#   - discipline: 90.0% match (45 matching values)
#
# Relationship: medals_data <-> Historical_Medal
# Common columns: ['country_code', 'country', 'discipline', 'event_type', 'name', 'event', 'medal_type']
#   - country_code: 100.0% match (92 matching values)
#   - country: 100.0% match (92 matching values)
#   - discipline: 100.0% match (45 matching values)
#   - event_type: 0.0% match (0 matching values)
#   - name: 0.1% match (1 matching values)
#   - event: 5.2% match (15 matching values)
#   - medal_type: 0.0% match (0 matching values)
#
# --- SUMMARY OF RELATIONSHIPS ---
# medalstotal_data <-> cleaned_teams: country_code, country
# medalstotal_data <-> medallists_data: country_code, country
# medalstotal_data <-> athlete_data: country_code
# medalstotal_data <-> medals_data: country_code, country
# medalstotal_data <-> Historical_Medal: country_code, country
# cleaned_teams <-> medallists_data: country_code, team, team_gender, country, discipline
# cleaned_teams <-> events: events
# cleaned_teams <-> athlete_data: country_code, team_gender, events, discipline, current, code
# cleaned_teams <-> medals_data: country_code, country, code, discipline
# cleaned_teams <-> Historical_Medal: country_code, country, discipline
# medallists_data <-> athlete_data: country_code, team_gender, discipline
# medallists_data <-> medals_data: country_code, medal_date, gender, country, medal_code, discipline, event_type, name, event, medal_type
# medallists_data <-> Historical_Medal: country_code, country, discipline, event_type, name, event, medal_type
# events <-> athlete_data: events
# athlete_data <-> medals_data: country_code, code, discipline
# athlete_data <-> Historical_Medal: country_code, discipline
# medals_data <-> Historical_Medal: country_code, country, discipline, event_type, name, event, medal_type

# %% [markdown]
# # Create network graph to visualize relationships

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Define nodes
nodes = [
    "medalstotal_data",
    "cleaned_teams",
    "medallists_data",
    "athlete_data",
    "medals_data",
    "Historical_Medal",
    "events"
]

G = nx.Graph()
for node in nodes:
    G.add_node(node, size=5)

# Define edges and labels
edges = [
    ("medalstotal_data", "cleaned_teams", "country_code, country"),
    ("medalstotal_data", "medallists_data", "country_code, country"),
    ("medalstotal_data", "athlete_data", "country_code"),
    ("medalstotal_data", "medals_data", "country_code, country"),
    ("medalstotal_data", "Historical_Medal", "country_code, country"),
    ("cleaned_teams", "medallists_data", "country_code, team, team_gender, country, discipline"),
    ("cleaned_teams", "events", "events"),
    ("cleaned_teams", "athlete_data", "country_code, team_gender, events, discipline, current, code"),
    ("cleaned_teams", "medals_data", "country_code, country, code, discipline"),
    ("cleaned_teams", "Historical_Medal", "country_code, country, discipline"),
    ("medallists_data", "athlete_data", "country_code, team_gender, discipline"),
    ("medallists_data", "medals_data", "country_code, medal_date, gender, country, medal_code, discipline, event_type, name, event, medal_type"),
    ("medallists_data", "Historical_Medal", "country_code, country, discipline, event_type, name, event, medal_type"),
    ("events", "athlete_data", "events"),
    ("athlete_data", "medals_data", "country_code, code, discipline"),
    ("athlete_data", "Historical_Medal", "country_code, discipline"),
    ("medals_data", "Historical_Medal", "country_code, country, discipline, event_type, name, event, medal_type"),
]

for u, v, label in edges:
    weight = len(label.split(","))
    G.add_edge(u, v, label=label, weight=weight)

plt.figure(figsize=(18, 13))

# Use spring layout with more spacing
pos = nx.spring_layout(G, k=2.2, seed=42)

# Manually adjust the 'events' node to be closer to the cluster
pos['events'][0] = pos['cleaned_teams'][0] * 0.7 + pos['athlete_data'][0] * 0.3
pos['events'][1] = pos['cleaned_teams'][1] * 0.7 + pos['athlete_data'][1] * 0.3

# Draw nodes
node_sizes = [2400 for _ in G.nodes()]
nx.draw_networkx_nodes(
    G, pos,
    node_size=node_sizes,
    node_color="#93c5fd",
    alpha=0.95,
    edgecolors="#3b82f6",
    linewidths=2
)

# Draw edges
nx.draw_networkx_edges(
    G, pos,
    width=2,
    alpha=0.5,
    edge_color="#64748b"
)

# Draw node labels
nx.draw_networkx_labels(
    G, pos,
    font_size=16,
    font_weight='bold',
    font_color='#334155',  # Dark slate, as in your image
    bbox=dict(
        facecolor='white',  # White background
        alpha=0.7,          # Semi-transparent
        edgecolor='none',
        boxstyle='round,pad=0.3'
    )
)


# Only show edge labels for edges with more than 1 column in common and not involving 'events'
edge_labels = nx.get_edge_attributes(G, 'label')
important_labels = {}
for e, l in edge_labels.items():
    if G[e[0]][e[1]]['weight'] > 1 and 'events' not in e:
        # Break long labels into lines
        words = l.split(", ")
        lines = []
        current_line = words[0]
        for word in words[1:]:
            if len(current_line + ", " + word) <= 30:
                current_line += ", " + word
            else:
                lines.append(current_line)
                current_line = word
        lines.append(current_line)
        important_labels[e] = "\n".join(lines)

nx.draw_networkx_edge_labels(
    G, pos,
    edge_labels=important_labels,
    font_size=11,
    font_color='black',
    bbox=dict(facecolor='white', alpha=0.7, edgecolor='none', boxstyle='round,pad=0.1'),
    rotate=False
)

plt.title("Entity Relationship Network Visualization", fontsize=20, pad=30)
plt.axis('off')
plt.tight_layout()
# plt.savefig('/Users/vidushi/Documents/Data_Visualization/project/ER-Diagram/entity_relationship_diagram_final.png', dpi=300, bbox_inches='tight')
plt.show()
